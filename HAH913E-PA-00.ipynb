# %% [markdown]
# # HAH913E Physical Activity — Assignment
#
# **Repository:** [https://github.com/amazayat90-jpg/MAM2ADMM-Series00-Git--amazayat90-jpg-](https://github.com/amazayat90-jpg/MAM2ADMM-Series00-Git--amazayat90-jpg-)
#
# **Team members:**
# - Amanielz_student (Amaniel Zayat)
